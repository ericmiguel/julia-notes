# %% [markdown]
# # API INMET
#
# A [API INMET](https://portal.inmet.gov.br/manual) possui diversos endpoints. Neste estudo, o objetivo é coletar e tratar séries temporais de estações meteorológicas.
#
# ## Lista de estações
#
# Para recuperar a lista de estações automáticas: https://apitempo.inmet.gov.br/estacoes/T
#
# ## Dados por estação
#
# Recuperar dados horários referentes a estação automática ou manual:
# - https://apitempo.inmet.gov.br/estacao/{data_inicial}/{data_final}/{cod_estacao}
# - https://apitempo.inmet.gov.br/estacao/2019-10-23/2019-10-23/A301
# - Sendo data no formato AAAA-MM-DD (ex: 2019-10-23)

# %%
using HTTP
using CSV
using JSON3
import Dates
using DataFrames

# %%
# configurações

# os dados serão coletados posto a posto em um intervalo de datas
df = Dates.DateFormat("y-m-d")
dataInicial = Dates.Date("2021-01-01", df)
dataFinal = Dates.Date("2021-01-02", df)

# cria um diretório para salvar os dados obtidos
diretorioPersistencia = "dados_estacoes"
Base.mkpath(diretorioPersistencia);

# %%
"""
Executa uma chamada GET simples a uma API.

# Examples
```jldoctest
julia> url = "https://apitempo.inmet.gov.br/estacao/2021-01-01/2021-01-02/A756"
julia> resposta = chamarAPI(url)
```
"""
function chamarAPI(url)
    # chamarAPI("https://apitempo.inmet.gov.br/estacao//2021-01-01/2021-01-02/A756")[1]
    # chamarAPI("https://apitempo.inmet.gov.br/estacao//2021-01-01/2021-01-02/A225")[1]
    resposta = HTTP.get(url)
    respostaString = String(resposta.body)
    return JSON3.read(respostaString, allow_inf=true)
end;

# %%
listaEstacoesAutomaticasJSON = chamarAPI("https://apitempo.inmet.gov.br/estacoes/T")
listaEstacoesAutomaticas = DataFrame(listaEstacoesAutomaticasJSON);

# filtrando apenas estações operantes
listaEstacoesAutomaticasOperantes = listaEstacoesAutomaticas[
    listaEstacoesAutomaticas[:, "CD_SITUACAO"] .== "Operante", :];

# %%
function coletarDadosEstacao(
        codigoEstacao::String,
        dataInicial::Dates.Date,
        dataFinal::Dates.Date
)::DataFrame
    # coletarDadosEstacao("A225", dataInicial, dataFinal)
    
    urlBaseDadosEstacoes = "https://apitempo.inmet.gov.br/estacao"
    urlQueryDadosEstacoes = "$(dataInicial)/$(dataFinal)/$(codigoEstacao)"
    urlCompleta = "$(urlBaseDadosEstacoes)/$(urlQueryDadosEstacoes)"
    
    # println(urlCompleta)

    serieEstacaoJSON = chamarAPI(urlCompleta)
    serieEstacao = DataFrame(serieEstacaoJSON)
    
    # substitui valores 'nothing' por 'missing'
    for coluna in names(serieEstacao)
        serieEstacao[!, coluna] = replace(
            serieEstacao[!, coluna], nothing => missing
        )
    end
    
    # se o dataframe gerador for vazio, a função irá parar
    if size(dropmissing(serieEstacao))[1] == 0
        error("não há dados disponíveis para a estação '$(codigoEstacao)'.")
    end
    
    return serieEstacao
end;

# %%
codigosEstacoes = listaEstacoesAutomaticasOperantes[:, "CD_ESTACAO"]

for codigoEstacao in codigosEstacoes
    try
        serieEstacao = coletarDadosEstacao(codigoEstacao, dataInicial, dataFinal)
        CSV.write("$(diretorioPersistencia)/$(codigoEstacao).csv", serieEstacao)
        println("Dados da estação '$(codigoEstacao)' obtidos.")
    catch e
        println("Não foi possível processar os dados de '$(codigoEstacao)': $(e)")
    end
    
    Base.sleep(1)
end
# Out:
# Dados da estação 'A756' obtidos.
# Dados da estação 'A045' obtidos.
# Dados da estação 'A549' obtidos.
# Dados da estação 'A826' obtidos.
# Dados da estação 'A615' obtidos.
# Não foi possível processar os dados de 'A053': ErrorException("não há dados disponíveis para a estação 'A053'.")
# Dados da estação 'A508' obtidos.
# Dados da estação 'A909' obtidos.
# Dados da estação 'A024' obtidos.
# Não foi possível processar os dados de 'A934': ErrorException("não há dados disponíveis para a estação 'A934'.")
# Dados da estação 'A336' obtidos.
# Dados da estação 'A434' obtidos.
# Dados da estação 'S701' obtidos.
# Dados da estação 'A340' obtidos.
# Dados da estação 'A409' obtidos.
# Dados da estação 'A566' obtidos.
# Não foi possível processar os dados de 'A013': ErrorException("não há dados disponíveis para a estação 'A013'.")
# Não foi possível processar os dados de 'A054': ErrorException("não há dados disponíveis para a estação 'A054'.")
# Dados da estação 'S702' obtidos.
# Dados da estação 'A867' obtidos.
# Dados da estação 'A505' obtidos.
# Não foi possível processar os dados de 'A309': ErrorException("não há dados disponíveis para a estação 'A309'.")
# Não foi possível processar os dados de 'A310': ErrorException("não há dados disponíveis para a estação 'A310'.")
# Dados da estação 'A736' obtidos.
# Não foi possível processar os dados de 'A606': ErrorException("não há dados disponíveis para a estação 'A606'.")
# Não foi possível processar os dados de 'A725': ErrorException("não há dados disponíveis para a estação 'A725'.")
# Dados da estação 'A220' obtidos.
# Não foi possível processar os dados de 'A375': ErrorException("não há dados disponíveis para a estação 'A375'.")
# Não foi possível processar os dados de 'S113': ErrorException("não há dados disponíveis para a estação 'S113'.")
# Dados da estação 'A565' obtidos.
# Dados da estação 'A502' obtidos.
# Dados da estação 'A429' obtidos.
# Não foi possível processar os dados de 'A741': ErrorException("não há dados disponíveis para a estação 'A741'.")
# Não foi possível processar os dados de 'A221': ErrorException("não há dados disponíveis para a estação 'A221'.")
# Não foi possível processar os dados de 'A402': ErrorException("não há dados disponíveis para a estação 'A402'.")
# Não foi possível processar os dados de 'A755': ErrorException("não há dados disponíveis para a estação 'A755'.")
# Dados da estação 'A705' obtidos.
# Dados da estação 'A201' obtidos.
# Dados da estação 'F501' obtidos.
# Dados da estação 'A840' obtidos.
# Dados da estação 'A765' obtidos.
# Não foi possível processar os dados de 'A845': ErrorException("não há dados disponíveis para a estação 'A845'.")
# Não foi possível processar os dados de 'A326': ErrorException("não há dados disponíveis para a estação 'A326'.")
# Não foi possível processar os dados de 'S122': ErrorException("não há dados disponíveis para a estação 'S122'.")
# Dados da estação 'A744' obtidos.
# Dados da estação 'A001' obtidos.
# Dados da estação 'A042' obtidos.
# Dados da estação 'A433' obtidos.
# Dados da estação 'S706' obtidos.
# Não foi possível processar os dados de 'A329': ErrorException("não há dados disponíveis para a estação 'A329'.")
# Dados da estação 'A859' obtidos.
# Não foi possível processar os dados de 'A023': ErrorException("não há dados disponíveis para a estação 'A023'.")
# Não foi possível processar os dados de 'A316': ErrorException("não há dados disponíveis para a estação 'A316'.")
# Não foi possível processar os dados de 'A530': ErrorException("não há dados disponíveis para a estação 'A530'.")
# Dados da estação 'A838' obtidos.
# Dados da estação 'A897' obtidos.
# Dados da estação 'A604' obtidos.
# Dados da estação 'A313' obtidos.
# Dados da estação 'A519' obtidos.
# Não foi possível processar os dados de 'A884': ErrorException("não há dados disponíveis para a estação 'A884'.")
# Dados da estação 'A702' obtidos.
# Não foi possível processar os dados de 'A912': ErrorException("não há dados disponíveis para a estação 'A912'.")
# Não foi possível processar os dados de 'A706': ErrorException("não há dados disponíveis para a estação 'A706'.")
# Dados da estação 'A607' obtidos.
# Não foi possível processar os dados de 'A620': ErrorException("não há dados disponíveis para a estação 'A620'.")
# Dados da estação 'A898' obtidos.
# Não foi possível processar os dados de 'A879': ErrorException("não há dados disponíveis para a estação 'A879'.")
# Não foi possível processar os dados de 'A811': ErrorException("não há dados disponíveis para a estação 'A811'.")
# Dados da estação 'A365' obtidos.
# Dados da estação 'A887' obtidos.
# Dados da estação 'A248' obtidos.
# Não foi possível processar os dados de 'A337': ErrorException("não há dados disponíveis para a estação 'A337'.")
# Dados da estação 'A554' obtidos.
# Dados da estação 'A629' obtidos.
# Dados da estação 'A205' obtidos.
# Dados da estação 'A742' obtidos.
# Dados da estação 'A202' obtidos.
# Dados da estação 'A034' obtidos.
# Não foi possível processar os dados de 'S106': ErrorException("não há dados disponíveis para a estação 'S106'.")
# Dados da estação 'A548' obtidos.
# Dados da estação 'A895' obtidos.
# Dados da estação 'A869' obtidos.
# Dados da estação 'A876' obtidos.
# Dados da estação 'A049' obtidos.
# Dados da estação 'B806' obtidos.
# Dados da estação 'A520' obtidos.
# Dados da estação 'A557' obtidos.
# Não foi possível processar os dados de 'A374': ErrorException("não há dados disponíveis para a estação 'A374'.")
# Não foi possível processar os dados de 'A416': ErrorException("não há dados disponíveis para a estação 'A416'.")
# Dados da estação 'A724' obtidos.
# Não foi possível processar os dados de 'A760': ErrorException("não há dados disponíveis para a estação 'A760'.")
# Não foi possível processar os dados de 'A720': ErrorException("não há dados disponíveis para a estação 'A720'.")
# Dados da estação 'A342' obtidos.
# Dados da estação 'A036' obtidos.
# Dados da estação 'A056' obtidos.
# Não foi possível processar os dados de 'S103': ErrorException("não há dados disponíveis para a estação 'S103'.")
# Dados da estação 'A853' obtidos.
# Dados da estação 'A901' obtidos.
# Não foi possível processar os dados de 'A448': ErrorException("não há dados disponíveis para a estação 'A448'.")
# Dados da estação 'A807' obtidos.
# Dados da estação 'A860' obtidos.
# Dados da estação 'A538' obtidos.
# Dados da estação 'A537' obtidos.
# Não foi possível processar os dados de 'A038': ErrorException("não há dados disponíveis para a estação 'A038'.")
# Dados da estação 'A848' obtidos.
# Dados da estação 'A564' obtidos.
# Dados da estação 'A252' obtidos.
# Dados da estação 'S107' obtidos.
# Não foi possível processar os dados de 'A881': ErrorException("não há dados disponíveis para a estação 'A881'.")
# Dados da estação 'A536' obtidos.
# Não foi possível processar os dados de 'S110': ErrorException("não há dados disponíveis para a estação 'S110'.")
# Não foi possível processar os dados de 'S120': ErrorException("não há dados disponíveis para a estação 'S120'.")
# Não foi possível processar os dados de 'S105': ErrorException("não há dados disponíveis para a estação 'S105'.")
# Dados da estação 'S117' obtidos.
# Não foi possível processar os dados de 'S104': ErrorException("não há dados disponíveis para a estação 'S104'.")
# Dados da estação 'A603' obtidos.
# Não foi possível processar os dados de 'A631': ErrorException("não há dados disponíveis para a estação 'A631'.")
# Dados da estação 'A029' obtidos.
# Dados da estação 'A893' obtidos.
# Dados da estação 'A828' obtidos.
# Dados da estação 'A442' obtidos.
# Dados da estação 'A351' obtidos.
# Dados da estação 'A535' obtidos.
# Não foi possível processar os dados de 'A311': ErrorException("não há dados disponíveis para a estação 'A311'.")
# Dados da estação 'A806' obtidos.
# Não foi possível processar os dados de 'A524': ErrorException("não há dados disponíveis para a estação 'A524'.")
# Não foi possível processar os dados de 'A039': ErrorException("não há dados disponíveis para a estação 'A039'.")
# Não foi possível processar os dados de 'A452': ErrorException("não há dados disponíveis para a estação 'A452'.")
# Dados da estação 'A305' obtidos.
# Não foi possível processar os dados de 'S101': ErrorException("não há dados disponíveis para a estação 'S101'.")
# Dados da estação 'A708' obtidos.
# Dados da estação 'A046' obtidos.
# Dados da estação 'A875' obtidos.
# Não foi possível processar os dados de 'A364': ErrorException("não há dados disponíveis para a estação 'A364'.")
# Não foi possível processar os dados de 'A022': ErrorException("não há dados disponíveis para a estação 'A022'.")
# Dados da estação 'A002' obtidos.
# Dados da estação 'A014' obtidos.
# Dados da estação 'A532' obtidos.
# Dados da estação 'A426' obtidos.
# Não foi possível processar os dados de 'A533': ErrorException("não há dados disponíveis para a estação 'A533'.")
# Não foi possível processar os dados de 'A019': ErrorException("não há dados disponíveis para a estação 'A019'.")
# Dados da estação 'A349' obtidos.
# Dados da estação 'A555' obtidos.
# Não foi possível processar os dados de 'S709': ErrorException("não há dados disponíveis para a estação 'S709'.")
# Dados da estação 'A319' obtidos.
# Não foi possível processar os dados de 'A410': ErrorException("não há dados disponíveis para a estação 'A410'.")
# Dados da estação 'A225' obtidos.
# Dados da estação 'A823' obtidos.
# Não foi possível processar os dados de 'A372': ErrorException("não há dados disponíveis para a estação 'A372'.")
# Dados da estação 'A424' obtidos.
# Dados da estação 'A417' obtidos.
# Não foi possível processar os dados de 'A408': ErrorException("não há dados disponíveis para a estação 'A408'.")
# Não foi possível processar os dados de 'A121': ErrorException("não há dados disponíveis para a estação 'A121'.")
# Dados da estação 'A550' obtidos.
# Dados da estação 'A015' obtidos.
# Dados da estação 'A714' obtidos.
# Dados da estação 'S710' obtidos.
# Dados da estação 'A752' obtidos.
# Não foi possível processar os dados de 'A635': ErrorException("não há dados disponíveis para a estação 'A635'.")
# Dados da estação 'A407' obtidos.
# Não foi possível processar os dados de 'A753': ErrorException("não há dados disponíveis para a estação 'A753'.")
# Dados da estação 'A818' obtidos.
# Dados da estação 'A709' obtidos.
# Dados da estação 'A836' obtidos.
# Não foi possível processar os dados de 'A339': ErrorException("não há dados disponíveis para a estação 'A339'.")
# Dados da estação 'A733' obtidos.
# Dados da estação 'A563' obtidos.
# Dados da estação 'A559' obtidos.
# Não foi possível processar os dados de 'A758': ErrorException("não há dados disponíveis para a estação 'A758'.")
# Dados da estação 'A016' obtidos.
# Dados da estação 'A450' obtidos.
# Dados da estação 'A841' obtidos.
# Dados da estação 'A320' obtidos.
# Dados da estação 'A553' obtidos.
# Dados da estação 'A821' obtidos.
# Dados da estação 'A920' obtidos.
# Dados da estação 'A518' obtidos.
# Não foi possível processar os dados de 'A111': ErrorException("não há dados disponíveis para a estação 'A111'.")
# Dados da estação 'A865' obtidos.
# Dados da estação 'A055' obtidos.
# Dados da estação 'A844' obtidos.
# Dados da estação 'S711' obtidos.
# Dados da estação 'B804' obtidos.
# Dados da estação 'A425' obtidos.
# Dados da estação 'A614' obtidos.
# Não foi possível processar os dados de 'A404': ErrorException("não há dados disponíveis para a estação 'A404'.")
# Dados da estação 'A012' obtidos.
# Dados da estação 'A608' obtidos.
# Não foi possível processar os dados de 'A412': ErrorException("não há dados disponíveis para a estação 'A412'.")
# Não foi possível processar os dados de 'A303': ErrorException("não há dados disponíveis para a estação 'A303'.")
# Dados da estação 'A567' obtidos.
# Não foi possível processar os dados de 'A864': ErrorException("não há dados disponíveis para a estação 'A864'.")
# Dados da estação 'A820' obtidos.
# Dados da estação 'A119' obtidos.
# Dados da estação 'A101' obtidos.
# Dados da estação 'A540' obtidos.
# Dados da estação 'A531' obtidos.
# Dados da estação 'A041' obtidos.
# Dados da estação 'A632' obtidos.
# Não foi possível processar os dados de 'A763': ErrorException("não há dados disponíveis para a estação 'A763'.")
# Dados da estação 'A835' obtidos.
# Dados da estação 'A539' obtidos.
# Dados da estação 'A526' obtidos.
# Dados da estação 'A032' obtidos.
# Não foi possível processar os dados de 'A509': ErrorException("não há dados disponíveis para a estação 'A509'.")
# Dados da estação 'A506' obtidos.
# Dados da estação 'A332' obtidos.
# Dados da estação 'A873' obtidos.
# Dados da estação 'A003' obtidos.
# Dados da estação 'A517' obtidos.
# Dados da estação 'A304' obtidos.
# Dados da estação 'A627' obtidos.
# Não foi possível processar os dados de 'A453': ErrorException("não há dados disponíveis para a estação 'A453'.")
# Dados da estação 'S712' obtidos.
# Não foi possível processar os dados de 'S713': ErrorException("não há dados disponíveis para a estação 'S713'.")
# Não foi possível processar os dados de 'A624': ErrorException("não há dados disponíveis para a estação 'A624'.")
# Não foi possível processar os dados de 'A623': ErrorException("não há dados disponíveis para a estação 'A623'.")
# Não foi possível processar os dados de 'A144': ErrorException("não há dados disponíveis para a estação 'A144'.")
# Não foi possível processar os dados de 'A235': ErrorException("não há dados disponíveis para a estação 'A235'.")
# Dados da estação 'A570' obtidos.
# Dados da estação 'A513' obtidos.
# Dados da estação 'S114' obtidos.
# Não foi possível processar os dados de 'A357': ErrorException("não há dados disponíveis para a estação 'A357'.")
# Dados da estação 'A009' obtidos.
# Dados da estação 'A856' obtidos.
# Dados da estação 'A327' obtidos.
# Dados da estação 'A521' obtidos.
# Dados da estação 'A571' obtidos.
# Dados da estação 'A010' obtidos.
# Dados da estação 'A047' obtidos.
# Dados da estação 'A619' obtidos.
# Dados da estação 'A027' obtidos.
# Dados da estação 'A308' obtidos.
# Dados da estação 'A102' obtidos.
# Dados da estação 'A529' obtidos.
# Dados da estação 'A839' obtidos.
# Dados da estação 'A516' obtidos.
# Dados da estação 'A321' obtidos.
# Dados da estação 'A562' obtidos.
# Dados da estação 'A523' obtidos.
# Dados da estação 'A330' obtidos.
# Dados da estação 'A020' obtidos.
# Dados da estação 'S714' obtidos.
# Não foi possível processar os dados de 'S116': ErrorException("não há dados disponíveis para a estação 'S116'.")
# Não foi possível processar os dados de 'S102': ErrorException("não há dados disponíveis para a estação 'S102'.")
# Não foi possível processar os dados de 'S115': ErrorException("não há dados disponíveis para a estação 'S115'.")
# Dados da estação 'A018' obtidos.
# Dados da estação 'A307' obtidos.
# Dados da estação 'A430' obtidos.
# Não foi possível processar os dados de 'A343': ErrorException("não há dados disponíveis para a estação 'A343'.")
# Não foi possível processar os dados de 'A371': ErrorException("não há dados disponíveis para a estação 'A371'.")
# Dados da estação 'A545' obtidos.
# Dados da estação 'A033' obtidos.
# Dados da estação 'A335' obtidos.
# Não foi possível processar os dados de 'A051': ErrorException("não há dados disponíveis para a estação 'A051'.")
# Dados da estação 'A419' obtidos.
# Dados da estação 'A703' obtidos.
# Não foi possível processar os dados de 'A005': ErrorException("não há dados disponíveis para a estação 'A005'.")
# Dados da estação 'A801' obtidos.
# Não foi possível processar os dados de 'A935': ErrorException("não há dados disponíveis para a estação 'A935'.")
# Dados da estação 'A244' obtidos.
# Não foi possível processar os dados de 'A723': ErrorException("não há dados disponíveis para a estação 'A723'.")
# Dados da estação 'A017' obtidos.
# Dados da estação 'A747' obtidos.
# Dados da estação 'A622' obtidos.
# Dados da estação 'A707' obtidos.
# Dados da estação 'A831' obtidos.
# Não foi possível processar os dados de 'A436': ErrorException("não há dados disponíveis para a estação 'A436'.")
# Não foi possível processar os dados de 'A325': ErrorException("não há dados disponíveis para a estação 'A325'.")
# Dados da estação 'A718' obtidos.
# Dados da estação 'A870' obtidos.
# Dados da estação 'A301' obtidos.
# Não foi possível processar os dados de 'A254': ErrorException("não há dados disponíveis para a estação 'A254'.")
# Não foi possível processar os dados de 'A766': ErrorException("não há dados disponíveis para a estação 'A766'.")
# Dados da estação 'A423' obtidos.
# Dados da estação 'A609' obtidos.
# Dados da estação 'S715' obtidos.
# Dados da estação 'A458' obtidos.
# Dados da estação 'A743' obtidos.
# Dados da estação 'A626' obtidos.
# Dados da estação 'A652' obtidos.
# Dados da estação 'A621' obtidos.
# Dados da estação 'A602' obtidos.
# Dados da estação 'A861' obtidos.
# Dados da estação 'A802' obtidos.
# Dados da estação 'A862' obtidos.
# Dados da estação 'A813' obtidos.
# Não foi possível processar os dados de 'A551': ErrorException("não há dados disponíveis para a estação 'A551'.")
# Dados da estação 'A050' obtidos.
# Não foi possível processar os dados de 'A125': ErrorException("não há dados disponíveis para a estação 'A125'.")
# Não foi possível processar os dados de 'A025': ErrorException("não há dados disponíveis para a estação 'A025'.")
# Não foi possível processar os dados de 'A907': ErrorException("não há dados disponíveis para a estação 'A907'.")
# Não foi possível processar os dados de 'A134': ErrorException("não há dados disponíveis para a estação 'A134'.")
# Dados da estação 'A525' obtidos.
# Não foi possível processar os dados de 'A370': ErrorException("não há dados disponíveis para a estação 'A370'.")
# Dados da estação 'A552' obtidos.
# Dados da estação 'A401' obtidos.
# Dados da estação 'A456' obtidos.
# Dados da estação 'A048' obtidos.
# Não foi possível processar os dados de 'S121': ErrorException("não há dados disponíveis para a estação 'S121'.")
# Dados da estação 'A803' obtidos.
# Não foi possível processar os dados de 'A256': ErrorException("não há dados disponíveis para a estação 'A256'.")
# Dados da estação 'A630' obtidos.
# Dados da estação 'S716' obtidos.
# Dados da estação 'A810' obtidos.
# Não foi possível processar os dados de 'A052': ErrorException("não há dados disponíveis para a estação 'A052'.")
# Não foi possível processar os dados de 'A613': ErrorException("não há dados disponíveis para a estação 'A613'.")
# Não foi possível processar os dados de 'A804': ErrorException("não há dados disponíveis para a estação 'A804'.")
# Dados da estação 'A833' obtidos.
# Dados da estação 'A805' obtidos.
# Dados da estação 'S108' obtidos.
# Dados da estação 'A830' obtidos.
# Dados da estação 'A711' obtidos.
# Não foi possível processar os dados de 'A921': ErrorException("não há dados disponíveis para a estação 'A921'.")
# Dados da estação 'A216' obtidos.
# Dados da estação 'A832' obtidos.
# Dados da estação 'A333' obtidos.
# Dados da estação 'A514' obtidos.
# Dados da estação 'A815' obtidos.
# Dados da estação 'A942' obtidos.
# Não foi possível processar os dados de 'A203': ErrorException("não há dados disponíveis para a estação 'A203'.")
# Dados da estação 'A356' obtidos.
# Dados da estação 'A616' obtidos.
# Dados da estação 'A715' obtidos.
# Não foi possível processar os dados de 'A031': ErrorException("não há dados disponíveis para a estação 'A031'.")
# Não foi possível processar os dados de 'A857': ErrorException("não há dados disponíveis para a estação 'A857'.")
# Dados da estação 'A771' obtidos.
# Dados da estação 'A701' obtidos.
# Não foi possível processar os dados de 'A345': ErrorException("não há dados disponíveis para a estação 'A345'.")
# Dados da estação 'A547' obtidos.
# Dados da estação 'A011' obtidos.
# Dados da estação 'A770' obtidos.
# Dados da estação 'A889' obtidos.
# Dados da estação 'A911' obtidos.
# Dados da estação 'A667' obtidos.
# Não foi possível processar os dados de 'A428': ErrorException("não há dados disponíveis para a estação 'A428'.")
# Dados da estação 'A894' obtidos.
# Dados da estação 'A601' obtidos.
# Não foi possível processar os dados de 'A943': ErrorException("não há dados disponíveis para a estação 'A943'.")
# Dados da estação 'A350' obtidos.
# Dados da estação 'A569' obtidos.
# Não foi possível processar os dados de 'A754': ErrorException("não há dados disponíveis para a estação 'A754'.")
# Não foi possível processar os dados de 'A659': ErrorException("não há dados disponíveis para a estação 'A659'.")
# Não foi possível processar os dados de 'A037': ErrorException("não há dados disponíveis para a estação 'A037'.")
# Dados da estação 'A837' obtidos.
# Dados da estação 'A713' obtidos.
# Dados da estação 'A328' obtidos.
# Dados da estação 'A899' obtidos.
# Dados da estação 'A527' obtidos.
# Não foi possível processar os dados de 'A312': ErrorException("não há dados disponíveis para a estação 'A312'.")
# Dados da estação 'A618' obtidos.
# Não foi possível processar os dados de 'S123': ErrorException("não há dados disponíveis para a estação 'S123'.")
# Não foi possível processar os dados de 'A882': ErrorException("não há dados disponíveis para a estação 'A882'.")
# Dados da estação 'A511' obtidos.
# Dados da estação 'A213' obtidos.
# Dados da estação 'A808' obtidos.
# Não foi possível processar os dados de 'A834': ErrorException("não há dados disponíveis para a estação 'A834'.")
# Não foi possível processar os dados de 'A704': ErrorException("não há dados disponíveis para a estação 'A704'.")
# Dados da estação 'A528' obtidos.
# Dados da estação 'A625' obtidos.
# Não foi possível processar os dados de 'A768': ErrorException("não há dados disponíveis para a estação 'A768'.")
# Dados da estação 'A886' obtidos.
# Dados da estação 'A568' obtidos.
# Dados da estação 'A507' obtidos.
# Não foi possível processar os dados de 'S111': ErrorException("não há dados disponíveis para a estação 'S111'.")
# Dados da estação 'A542' obtidos.
# Dados da estação 'A809' obtidos.
# Dados da estação 'A814' obtidos.
# Dados da estação 'A880' obtidos.
# Dados da estação 'A611' obtidos.
# Dados da estação 'A734' obtidos.
# Não foi possível processar os dados de 'A515': ErrorException("não há dados disponíveis para a estação 'A515'.")
# Dados da estação 'A633' obtidos.
# Dados da estação 'A510' obtidos.
# Não foi possível processar os dados de 'A938': ErrorException("não há dados disponíveis para a estação 'A938'.")
# Dados da estação 'A612' obtidos.
# Dados da estação 'A729' obtidos.
# Dados da estação 'A858' obtidos.
# Dados da estação 'A247' obtidos.
# Não foi possível processar os dados de 'A255': ErrorException("não há dados disponíveis para a estação 'A255'.")
