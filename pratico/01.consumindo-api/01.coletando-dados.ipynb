# %%
using HTTP
using CSV
using JSON3
import Dates
using DataFrames

# %% [markdown]
# # API INMET
#
# A [API INMET](https://portal.inmet.gov.br/manual) possui diversos endpoints. Neste estudo, o objetivo é coletar e tratar séries temporais de estações meteorológicas.

# %%
function chamarAPI(url)
    try
        resposta = HTTP.get(url)
        return JSON3.read(String(resposta.body))
    catch e
        return "Um erro aconteceu: $(e)"
    end
end;

# %% [markdown]
# ## Lista de estações
#
# Para recuperar a lista de estações automáticas: https://apitempo.inmet.gov.br/estacoes/T

# %%
listaEstacoesAutomaticasJSON = chamarAPI("https://apitempo.inmet.gov.br/estacoes/T")
listaEstacoesAutomaticas = DataFrame(listaEstacoesAutomaticasJSON);

# %%
# nome das colunas
names(listaEstacoesAutomaticas);

# %%
# filtrando apenas estações operantes
listaEstacoesAutomaticasOperantes = listaEstacoesAutomaticas[
    listaEstacoesAutomaticas[:, "CD_SITUACAO"] .== "Operante", :];

# %% [markdown]
# ## Dados por estação
#
# Recuperar dados horários referentes a estação automática ou manual:
# - https://apitempo.inmet.gov.br/estacao/{data_inicial}/{data_final}/{cod_estacao}
# - https://apitempo.inmet.gov.br/estacao/2019-10-23/2019-10-23/A301
# - Sendo data no formato AAAA-MM-DD (ex: 2019-10-23)

# %%
# os dados serão coletados posto a posto em um intervalo de datas
df = Dates.DateFormat("y-m-d")
dataInicial = Dates.Date("2021-01-01", df)
dataFinal = Dates.Date("2021-01-02", df)

# cria um diretório para salvar os dados obtidos
diretorioPersistencia = "dados_estacoes"
mkpath(diretorioPersistencia);

# %%
function coletarDadosEstacao(
        codigoEstacao::String,
        dataInicial::Dates.Date,
        dataFinal::Dates.Date)::DataFrame
    
    urlBaseDadosEstacoes = "https://apitempo.inmet.gov.br/estacao/"
    urlQueryDadosEstacoes = "$(dataInicial)/$(dataFinal)/$(codigoEstacao)"
    serieEstacaoJSON = chamarAPI("$(urlBaseDadosEstacoes)/$(urlQueryDadosEstacoes)")
    serieEstacao = DataFrame(serieEstacaoJSON)
    
    # substitui valores 'nothing' por 'missing'
    for coluna in names(serieEstacao)
        serieEstacao[!, coluna] = replace(
            serieEstacao[!, coluna], nothing => missing
        )
    end
    
    return serieEstacao
end;

# %%
codigosEstacoes = listaEstacoesAutomaticasOperantes[:, "CD_ESTACAO"]

for codigoEstacao in codigosEstacoes
    try
        serieEstacao = coletarDadosEstacao(codigoEstacao, dataInicial, dataFinal)
        CSV.write("$(diretorioPersistencia)/$(codigoEstacao).csv", serieEstacao)
        println("Dados da estação '$(codigoEstacao)' obtidos.")
    catch e
        println("Não foi possível processar os dados de '$(codigoEstacao)'. $e")
    end
end
# Out:
# Dados da estação 'A756' obtidos.
# Dados da estação 'A045' obtidos.
# Dados da estação 'A549' obtidos.
# Dados da estação 'A826' obtidos.
# Dados da estação 'A615' obtidos.
# Dados da estação 'A053' obtidos.
# Dados da estação 'A508' obtidos.
# Dados da estação 'A909' obtidos.
# Dados da estação 'A024' obtidos.
# Dados da estação 'A934' obtidos.
# Dados da estação 'A336' obtidos.
# Dados da estação 'A434' obtidos.
# Dados da estação 'S701' obtidos.
# Dados da estação 'A340' obtidos.
# Dados da estação 'A409' obtidos.
# Dados da estação 'A566' obtidos.
# Dados da estação 'A013' obtidos.
# Dados da estação 'A054' obtidos.
# Dados da estação 'S702' obtidos.
# Dados da estação 'A867' obtidos.
# Dados da estação 'A505' obtidos.
# Dados da estação 'A309' obtidos.
# Dados da estação 'A310' obtidos.
# Dados da estação 'A736' obtidos.
# Dados da estação 'A606' obtidos.
# Dados da estação 'A725' obtidos.
# Dados da estação 'A220' obtidos.
# Dados da estação 'A375' obtidos.
# Dados da estação 'S113' obtidos.
# Dados da estação 'A565' obtidos.
# Dados da estação 'A502' obtidos.
# Dados da estação 'A429' obtidos.
# Dados da estação 'A741' obtidos.
# Dados da estação 'A221' obtidos.
# Dados da estação 'A402' obtidos.
# Dados da estação 'A755' obtidos.
# Dados da estação 'A705' obtidos.
# Dados da estação 'A201' obtidos.
# Dados da estação 'F501' obtidos.
# Dados da estação 'A840' obtidos.
# Dados da estação 'A765' obtidos.
# Dados da estação 'A845' obtidos.
# Dados da estação 'A326' obtidos.
# Dados da estação 'S122' obtidos.
# Dados da estação 'A744' obtidos.
# Dados da estação 'A001' obtidos.
# Dados da estação 'A042' obtidos.
# Dados da estação 'A433' obtidos.
# Dados da estação 'S706' obtidos.
# Dados da estação 'A329' obtidos.
# Dados da estação 'A859' obtidos.
# Dados da estação 'A023' obtidos.
# Dados da estação 'A316' obtidos.
# Dados da estação 'A530' obtidos.
# Dados da estação 'A838' obtidos.
# Dados da estação 'A897' obtidos.
# Dados da estação 'A604' obtidos.
# Dados da estação 'A313' obtidos.
# Dados da estação 'A519' obtidos.
# Dados da estação 'A884' obtidos.
# Dados da estação 'A702' obtidos.
# Dados da estação 'A912' obtidos.
# Dados da estação 'A706' obtidos.
# Dados da estação 'A607' obtidos.
# Dados da estação 'A620' obtidos.
# Dados da estação 'A898' obtidos.
# Dados da estação 'A879' obtidos.
# Dados da estação 'A811' obtidos.
# Dados da estação 'A365' obtidos.
# Dados da estação 'A887' obtidos.
# Dados da estação 'A248' obtidos.
# Dados da estação 'A337' obtidos.
# Dados da estação 'A554' obtidos.
# Dados da estação 'A629' obtidos.
# Dados da estação 'A205' obtidos.
# Dados da estação 'A742' obtidos.
# Dados da estação 'A202' obtidos.
# Dados da estação 'A034' obtidos.
# Dados da estação 'S106' obtidos.
# Dados da estação 'A548' obtidos.
# Dados da estação 'A895' obtidos.
# Dados da estação 'A869' obtidos.
# Dados da estação 'A876' obtidos.
# Dados da estação 'A049' obtidos.
# Dados da estação 'B806' obtidos.
# Dados da estação 'A520' obtidos.
# Dados da estação 'A557' obtidos.
# Dados da estação 'A374' obtidos.
# Dados da estação 'A416' obtidos.
# Dados da estação 'A724' obtidos.
# Dados da estação 'A760' obtidos.
# Dados da estação 'A720' obtidos.
# Dados da estação 'A342' obtidos.
# Dados da estação 'A036' obtidos.
# Dados da estação 'A056' obtidos.
# Dados da estação 'S103' obtidos.
# Dados da estação 'A853' obtidos.
# Dados da estação 'A901' obtidos.
# Dados da estação 'A448' obtidos.
# Dados da estação 'A807' obtidos.
# Dados da estação 'A860' obtidos.
# Dados da estação 'A538' obtidos.
# Dados da estação 'A537' obtidos.
# Dados da estação 'A038' obtidos.
# Dados da estação 'A848' obtidos.
# Dados da estação 'A564' obtidos.
# Dados da estação 'A252' obtidos.
# Dados da estação 'S107' obtidos.
# Dados da estação 'A881' obtidos.
# Dados da estação 'A536' obtidos.
# Dados da estação 'S110' obtidos.
# Dados da estação 'S120' obtidos.
# Dados da estação 'S105' obtidos.
# Dados da estação 'S117' obtidos.
# Dados da estação 'S104' obtidos.
# Dados da estação 'A603' obtidos.
# Dados da estação 'A631' obtidos.
# Dados da estação 'A029' obtidos.
# Dados da estação 'A893' obtidos.
# Dados da estação 'A828' obtidos.
# Dados da estação 'A442' obtidos.
# Dados da estação 'A351' obtidos.
# Dados da estação 'A535' obtidos.
# Dados da estação 'A311' obtidos.
# Dados da estação 'A806' obtidos.
# Dados da estação 'A524' obtidos.
# Dados da estação 'A039' obtidos.
# Dados da estação 'A452' obtidos.
# Dados da estação 'A305' obtidos.
# Dados da estação 'S101' obtidos.
# Dados da estação 'A708' obtidos.
# Dados da estação 'A046' obtidos.
# Dados da estação 'A875' obtidos.
# Dados da estação 'A364' obtidos.
# Dados da estação 'A022' obtidos.
# Dados da estação 'A002' obtidos.
# Dados da estação 'A014' obtidos.
# Dados da estação 'A532' obtidos.
# Dados da estação 'A426' obtidos.
# Dados da estação 'A533' obtidos.
# Dados da estação 'A019' obtidos.
# Dados da estação 'A349' obtidos.
# Dados da estação 'A555' obtidos.
# Dados da estação 'S709' obtidos.
# Dados da estação 'A319' obtidos.
# Dados da estação 'A410' obtidos.
# Dados da estação 'A225' obtidos.
# Dados da estação 'A823' obtidos.
# Dados da estação 'A372' obtidos.
# Dados da estação 'A424' obtidos.
# Dados da estação 'A417' obtidos.
# Dados da estação 'A408' obtidos.
# Dados da estação 'A121' obtidos.
# Dados da estação 'A550' obtidos.
# Dados da estação 'A015' obtidos.
# Dados da estação 'A714' obtidos.
# Dados da estação 'S710' obtidos.
# Dados da estação 'A752' obtidos.
# Não foi possível processar os dados de 'A635'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A407'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A753'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A818'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A709'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A836'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A339'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A733'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A563'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A559'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A758'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A016'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A450'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A841'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A320'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A553'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A821'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A920'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A518'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A111'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A865'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A055'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A844'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S711'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'B804'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A425'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A614'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A404'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A012'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A608'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A412'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A303'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A567'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A864'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A820'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A119'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A101'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A540'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A531'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A041'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A632'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A763'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A835'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A539'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A526'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A032'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A509'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A506'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A332'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A873'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A003'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A517'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A304'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A627'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A453'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S712'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S713'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A624'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A623'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A144'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A235'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A570'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A513'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S114'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A357'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A009'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A856'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A327'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A521'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A571'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A010'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A047'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A619'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A027'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A308'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A102'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A529'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A839'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A516'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A321'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A562'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A523'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A330'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A020'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S714'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S116'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S102'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S115'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A018'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A307'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A430'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A343'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A371'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A545'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A033'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A335'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A051'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A419'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A703'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A005'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A801'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A935'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A244'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A723'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A017'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A747'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A622'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A707'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A831'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A436'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A325'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A718'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A870'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A301'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A254'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A766'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A423'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A609'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S715'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A458'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A743'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A626'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A652'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A621'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A602'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A861'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A802'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A862'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A813'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A551'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A050'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A125'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A025'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A907'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A134'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A525'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A370'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A552'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A401'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A456'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A048'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S121'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A803'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A256'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A630'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S716'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A810'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A052'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A613'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A804'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A833'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A805'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S108'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A830'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A711'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A921'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A216'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A832'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A333'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A514'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A815'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A942'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A203'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A356'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A616'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A715'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A031'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A857'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A771'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A701'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A345'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A547'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A011'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A770'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A889'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A911'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A667'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A428'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A894'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A601'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A943'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A350'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A569'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A754'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A659'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A037'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A837'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A713'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A328'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A899'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A527'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A312'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A618'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S123'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A882'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A511'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A213'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A808'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A834'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A704'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A528'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A625'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A768'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A886'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A568'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A507'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'S111'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A542'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A809'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A814'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A880'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A611'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A734'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A515'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A633'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A510'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A938'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A612'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A729'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A858'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A247'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
# Não foi possível processar os dados de 'A255'. ArgumentError("'String' iterates 'Char' values, which doesn't satisfy the Tables.jl `AbstractRow` interface")
